# %% [markdown]
# # Exploratory Data Analysis

# %%
#load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data_clean.csv")
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data.tail(10)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 148         149   30.0    193.0   6.9     70     9   26  2010    70       C
# 149         150    NaN    145.0  13.2     77     9   27  2010    77      PS
# 150         151   14.0    191.0  14.3     75     9   28  2010    75       S
# 151         152   18.0    131.0   8.0     76     9   29  2010    76      PS
# 152         153   20.0    223.0  11.5     68     9   30  2010    68       S
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
#Data Structure
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
data.shape[1]
# Out:
# 10

# %%
#data types
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
data['Year'].unique()
# Out:
# array([2010])

# %% [markdown]
# # Data type conversion

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data["Month"].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
data['Month']=pd.to_numeric(data['Month'],errors="coerce") #[1,1.5,NAN] january NA

data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')# coerce will introduce NA values for non numeric data in the columns

data['Weather']=data['Weather'].astype('category')           #data['Wind']=data['Wind'].astype('int64')

# %%
data.dtypes
# Out:
# Unnamed: 0       int64
# Ozone          float64
# Solar.R        float64
# Wind           float64
# Temp C         float64
# Month          float64
# Day              int64
# Year             int64
# Temp             int64
# Weather       category
# dtype: object

# %%
data['Unnamed: 0'].nunique()
# Out:
# 158

# %% [markdown]
# ####More on data type conversions
# [link text](https://stackoverflow.com/questions/15891038/change-column-type-in-pandas)

# %%
data1=data.drop(['Unnamed: 0','Year','Temp C'], axis = 1)
data1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4    5.0    1    67       S
# 1     36.0    118.0   8.0    5.0    2    72       C
# 2     12.0    149.0  12.6    5.0    3    74      PS
# 3     18.0    313.0  11.5    5.0    4    62       S
# 4      NaN      NaN  14.3    5.0    5    56       S
# ..     ...      ...   ...    ...  ...   ...     ...
# 153   41.0    190.0   7.4    5.0    1    67       C
# 154   30.0    193.0   6.9    9.0   26    70      PS
# 155    NaN    145.0  13.2    9.0   27    77       S
# 156   14.0    191.0  14.3    9.0   28    75       S
# 157   18.0    131.0   8.0    9.0   29    76       C
#
# [158 rows x 7 columns]

# %%
data1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156     True
# 157    False
# Length: 158, dtype: bool

# %%
#Print the duplicated rows
data1[data1.duplicated(keep=False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 150   14.0    191.0  14.3    9.0   28    75       S
# 156   14.0    191.0  14.3    9.0   28    75       S

# %%
data_cleaned1=data1.drop_duplicates()

# %%
help(data1.duplicated)
# Out:
# Help on method duplicated in module pandas.core.frame:
#
# duplicated(subset: 'Hashable | Sequence[Hashable] | None' = None, keep: 'DropKeep' = 'first') -> 'Series' method of pandas.core.frame.DataFrame instance
#     Return boolean Series denoting duplicate rows.
#
#     Considering certain columns is optional.
#
#     Parameters
#     ----------
#     subset : column label or sequence of labels, optional
#         Only consider certain columns for identifying duplicates, by
#         default use all of the columns.
#     keep : {'first', 'last', False}, default 'first'
#         Determines which duplicates (if any) to mark.
#
#         - ``first`` : Mark duplicates as ``True`` except for the first occurrence.
#         - ``last`` : Mark duplicates as ``True`` except for the last occurrence.
#         - False : Mark all duplicates as ``True``.
#
#     Returns
#     -------
#     Series
#         Boolean series for each duplicated rows.
#
#     See Also
#     --------
#     Index.duplicated : Equivalent method on index.
#     Series.duplicated : Equivalent method on Series.
#     Series.drop_duplicates : Remove duplicate values from Series.
#     DataFrame.drop_duplicates : Remove duplicate values from DataFrame.
#
#     Examples
#     --------
#     Consider dataset containing ramen rating.
#
#     >>> df = pd.DataFrame({
#     ...     'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
#     ...     'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
#     ...     'rating': [4, 4, 3.5, 15, 5]
#     ... })
#     >>> df
#         brand style  rating
#     0  Yum Yum   cup     4.0
#     1  Yum Yum   cup     4.0
#     2  Indomie   cup     3.5
#     3  Indomie  pack    15.0
#     4  Indomie  pack     5.0
#
#     By default, for each set of duplicated values, the first occurrence
#     is set on False and all others on True.
#
#     >>> df.duplicated()
#     0    False
#     1     True
#     2    False
#     3    False
#     4    False
#     dtype: bool
#
#     By using 'last', the last occurrence of each set of duplicated values
#     is set on False and all others on True.
#
#     >>> df.duplicated(keep='last')
#     0     True
#     1    False
#     2    False
#     3    False
#     4    False
#     dtype: bool
#
#     By setting ``keep`` on False, all duplicates are True.
#
#     >>> df.duplicated(keep=False)
#     0     True
#     1     True
#     2    False
#     3    False
#     4    False
#     dtype: bool
#
#     To find duplicates on specific column(s), use ``subset``.
#
#     >>> df.duplicated(subset=['brand'])
#     0    False
#     1     True
#     2    False
#     3     True
#     4     True
#     dtype: bool

# %%
data_cleaned1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar.R  150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Temp     157 non-null    int64
#  6   Weather  154 non-null    category
# dtypes: category(1), float64(4), int64(2)
# memory usage: 8.9 KB

# %%
data_cleaned1[data_cleaned1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Month, Day, Temp, Weather]
# Index: []

# %% [markdown]
# # Duplicates

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
#Count of duplicated rows
data[data.duplicated()].shape[0]
# Out:
# 0

# %%
data.columns[data.columns.duplicated()]   #to check duplicated columns
# Out:
# Index([], dtype='object')

# %%
data_cleaned1=data.drop_duplicates()
#data.drop_duplicates(inplace=True)|

# %%
data_cleaned1.tail()

data_cleaned1.reset_index(inplace=True)

# %%
data_cleaned1
# Out:
#      index  Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp  \
# 0        0           1   41.0    190.0   7.4    67.0    5.0    1  2010    67
# 1        1           2   36.0    118.0   8.0    72.0    5.0    2  2010    72
# 2        2           3   12.0    149.0  12.6    74.0    5.0    3  2010    74
# 3        3           4   18.0    313.0  11.5    62.0    5.0    4  2010    62
# 4        4           5    NaN      NaN  14.3    56.0    5.0    5  2010    56
# ..     ...         ...    ...      ...   ...     ...    ...  ...   ...   ...
# 153    153         154   41.0    190.0   7.4    67.0    5.0    1  2010    67
# 154    154         155   30.0    193.0   6.9    70.0    9.0   26  2010    70
# 155    155         156    NaN    145.0  13.2    77.0    9.0   27  2010    77
# 156    156         157   14.0    191.0  14.3    75.0    9.0   28  2010    75
# 157    157         158   18.0    131.0   8.0    76.0    9.0   29  2010    76
#
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 11 columns]

# %% [markdown]
# # Drop columns

# %%
data_cleaned1.drop(['Unnamed: 0','index','Temp C','Year'],axis=1,inplace=True)

# %%
#data-cleaned1.drop('index',axis=1)

# %%
data_cleaned1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4    5.0    1    67       S
# 1     36.0    118.0   8.0    5.0    2    72       C
# 2     12.0    149.0  12.6    5.0    3    74      PS
# 3     18.0    313.0  11.5    5.0    4    62       S
# 4      NaN      NaN  14.3    5.0    5    56       S
# ..     ...      ...   ...    ...  ...   ...     ...
# 153   41.0    190.0   7.4    5.0    1    67       C
# 154   30.0    193.0   6.9    9.0   26    70      PS
# 155    NaN    145.0  13.2    9.0   27    77       S
# 156   14.0    191.0  14.3    9.0   28    75       S
# 157   18.0    131.0   8.0    9.0   29    76       C
#
# [158 rows x 7 columns]

# %% [markdown]
# # Rename the columns

# %%
#rename the Solar column
#data_cleaned3 = data_cleaned2.rename({'Solar.R': 'Solar','Temp':'Temperature'}, axis=1)
data_cleaned1.rename({'Solar.R': 'Solar','Temp':'Temperature'}, axis=1,inplace=True)

# %%
data_cleaned1
# Out:
#      Ozone  Solar  Wind  Month  Day  Temperature Weather
# 0     41.0  190.0   7.4    5.0    1           67       S
# 1     36.0  118.0   8.0    5.0    2           72       C
# 2     12.0  149.0  12.6    5.0    3           74      PS
# 3     18.0  313.0  11.5    5.0    4           62       S
# 4      NaN    NaN  14.3    5.0    5           56       S
# ..     ...    ...   ...    ...  ...          ...     ...
# 153   41.0  190.0   7.4    5.0    1           67       C
# 154   30.0  193.0   6.9    9.0   26           70      PS
# 155    NaN  145.0  13.2    9.0   27           77       S
# 156   14.0  191.0  14.3    9.0   28           75       S
# 157   18.0  131.0   8.0    9.0   29           76       C
#
# [158 rows x 7 columns]

# %%
data_cleaned1.describe()
# Out:
#             Ozone       Solar        Wind       Month         Day  Temperature
# count  120.000000  151.000000  158.000000  157.000000  158.000000   158.000000
# mean    41.583333  185.403974    9.957595    7.044586   16.006329    77.727848
# std     32.620709   88.723103    3.511261    1.433768    8.997166     9.377877
# min      1.000000    7.000000    1.700000    5.000000    1.000000    56.000000
# 25%     18.000000  119.000000    7.400000    6.000000    8.000000    72.000000
# 50%     30.500000  197.000000    9.700000    7.000000   16.000000    78.500000
# 75%     61.500000  257.000000   11.875000    8.000000   24.000000    84.000000
# max    168.000000  334.000000   20.700000    9.000000   31.000000    97.000000

# %%
data_cleaned1.Ozone.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # Missing Values and Imputation

# %%
data_cleaned1.isnull().sum()    ####to find num of null values in each column
# Out:
# Ozone          38
# Solar           7
# Wind            0
# Month           1
# Day             0
# Temperature     0
# Weather         3
# dtype: int64

# %%
import seaborn as sns
sns.color_palette('Set2') #viridis,winter
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254)]

# %%
sns.set_palette('Set2')

# %%
data_cleaned1.isnull()
# Out:
#      Ozone  Solar   Wind  Month    Day  Temperature  Weather
# 0    False  False  False  False  False        False    False
# 1    False  False  False  False  False        False    False
# 2    False  False  False  False  False        False    False
# 3    False  False  False  False  False        False    False
# 4     True   True  False  False  False        False    False
# ..     ...    ...    ...    ...    ...          ...      ...
# 153  False  False  False  False  False        False    False
# 154  False  False  False  False  False        False    False
# 155   True  False  False  False  False        False    False
# 156  False  False  False  False  False        False    False
# 157  False  False  False  False  False        False    False
#
# [158 rows x 7 columns]

# %%
import seaborn as sns
cols = data_cleaned1.columns
colours = ['red', 'yellow']#specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data_cleaned1[cols].isnull(),
            cmap=colours)
# Out:
# <Axes: >

# %% [markdown]
# data_of_nulls = data_cleaned3[cols].isnull()
# column_names = list(data_of_nulls.columns)
#
#
# for i in column_names:
#     if True in list(data_of_nulls[i]):
#         print(i)

# %%
data_cleaned1.isnull().sum()
# Out:
# Ozone          38
# Solar           7
# Wind            0
# Month           1
# Day             0
# Temperature     0
# Weather         3
# dtype: int64

# %%
data_cleaned1[data_cleaned1.isnull().any(axis=1)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temperature Weather
# 4      NaN    NaN  14.3    5.0    5           56       S
# 5     28.0    NaN  14.9    5.0    6           66       C
# 9      NaN  194.0   8.6    5.0   10           69       S
# 10     7.0    NaN   6.9    5.0   11           74       C
# 23    32.0   92.0  12.0    NaN   24           61       C
# 24     NaN   66.0  16.6    5.0   25           57      PS
# 25     NaN  266.0  14.9    5.0   26           58       C
# 26     NaN    NaN   8.0    5.0   27           57      PS
# 31     NaN  286.0   8.6    6.0    1           78       S
# 32     NaN  287.0   9.7    6.0    2           74       C
# 33     NaN  242.0  16.1    6.0    3           67      PS
# 34     NaN  186.0   9.2    6.0    4           84       C
# 35     NaN  220.0   8.6    6.0    5           85      PS
# 36     NaN  264.0  14.3    6.0    6           79       C
# 38     NaN  273.0   6.9    6.0    8           87       S
# 41     NaN  259.0  10.9    6.0   11           93       C
# 42     NaN  250.0   9.2    6.0   12           92      PS
# 44     NaN  332.0  13.8    6.0   14           80       S
# 45     NaN  322.0  11.5    6.0   15           79       C
# 51     NaN  150.0   6.3    6.0   21           77       S
# 52     NaN   59.0   1.7    6.0   22           76       C
# 53     NaN   91.0   4.6    6.0   23           76      PS
# 54     NaN  250.0   6.3    6.0   24           76       S
# 55     NaN  135.0   8.0    6.0   25           75       C
# 56     NaN  127.0   8.0    6.0   26           78      PS
# 57     NaN   47.0  10.3    6.0   27           73       C
# 58     NaN   98.0  11.5    6.0   28           80      PS
# 59     NaN   31.0  14.9    6.0   29           77       S
# 60     NaN  138.0   8.0    6.0   30           83       S
# 64     NaN  101.0  10.9    7.0    4           84       S
# 71     NaN  139.0   8.6    7.0   11           82       S
# 74     NaN  291.0  14.9    7.0   14           91       C
# 82     NaN  258.0   9.7    7.0   22           81       S
# 83     NaN  295.0  11.5    7.0   23           82       C
# 87    52.0   82.0  12.0    7.0   27           86     NaN
# 93     9.0   24.0  13.8    8.0    2           81     NaN
# 95    78.0    NaN   6.9    8.0    4           86     NaN
# 96    35.0    NaN   7.4    8.0    5           85       S
# 97    66.0    NaN   4.6    8.0    6           87       C
# 101    NaN  222.0   8.6    8.0   10           92      PS
# 102    NaN  137.0  11.5    8.0   11           86       S
# 106    NaN   64.0  11.5    8.0   15           79       C
# 114    NaN  255.0  12.6    8.0   23           75      PS
# 118    NaN  153.0   5.7    8.0   27           88       S
# 149    NaN  145.0  13.2    9.0   27           77      PS
# 155    NaN  145.0  13.2    9.0   27           77       S

# %%
data_cleaned1.shape
# Out:
# (158, 7)

# %%
data_cleaned2=data_cleaned1.dropna()

# %%
data_cleaned2.shape
# Out:
# (112, 7)

# %%
data_cleaned2.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          0
# Day            0
# Temperature    0
# Weather        0
# dtype: int64

# %%
data_cleaned1.isnull().sum()
# Out:
# Ozone          38
# Solar           7
# Wind            0
# Month           1
# Day             0
# Temperature     0
# Weather         3
# dtype: int64

# %%
# data_cleaned1.Ozone.plot(kind='box')
# # plt.show()
data_cleaned1.Ozone.hist()
# Out:
# <Axes: >

# %%
data_cleaned1.Solar.plot(kind='box')
# Out:
# <Axes: >

# %%
#rename the Solar column
#data_cleaned4 = data_cleaned1.rename({'Solar.R': 'Solar'}, axis=1)

# %%
#data_cleaned4.info()

# %%
#imputing the null values

# replacing the null values with median of the column

oz_med=data_cleaned1.Ozone.median()

data_cleaned1['Ozone']=data_cleaned1['Ozone'].fillna(oz_med)

# %%
data_cleaned1.Ozone.plot(kind="box")
plt.show()
data_cleaned1["Ozone"].hist()
# Out:
# <Axes: >

# %%
data_cleaned1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ozone        158 non-null    float64
#  1   Solar        151 non-null    float64
#  2   Wind         158 non-null    float64
#  3   Month        157 non-null    float64
#  4   Day          158 non-null    int64
#  5   Temperature  158 non-null    int64
#  6   Weather      155 non-null    category
# dtypes: category(1), float64(4), int64(2)
# memory usage: 7.8 KB

# %%
data_cleaned1.Solar.plot(kind='box')
# Out:
# <Axes: >

# %%
#Mean Imputationa
mean = data_cleaned1['Solar'].mean()
print(mean)

data_cleaned1['Solar']=data_cleaned1['Solar'].fillna(mean)
# Out:
# 185.40397350993376

# %%
data_cleaned1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ozone        158 non-null    float64
#  1   Solar        158 non-null    float64
#  2   Wind         158 non-null    float64
#  3   Month        157 non-null    float64
#  4   Day          158 non-null    int64
#  5   Temperature  158 non-null    int64
#  6   Weather      155 non-null    category
# dtypes: category(1), float64(4), int64(2)
# memory usage: 7.8 KB

# %%
data_cleaned1.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          1
# Day            0
# Temperature    0
# Weather        3
# dtype: int64

# %%
data_cleaned1.Month.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
data_cleaned1.Weather.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Weather'>

# %%
data_cleaned1.Weather.mode()[0]
# Out:
# 'S'

# %%
mode_weather=data_cleaned1.Weather.mode()[0]
mode_weather
# Out:
# 'S'

# %%
data_cleaned1['Weather']=data_cleaned1.Weather.fillna(mode_weather)

# %%
data_cleaned1.Weather.unique()
# Out:
# ['S', 'C', 'PS']
# Categories (3, object): ['C', 'PS', 'S']

# %%
data_cleaned1.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          1
# Day            0
# Temperature    0
# Weather        0
# dtype: int64

# %%
data_cleaned1.dropna(inplace=True)

# %%
#help(data.dropna)

# %%
data_2=data_cleaned1.copy()  #for alt. outlier treatment
data_3=data_cleaned1.copy()

# %%
data_cleaned1.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          0
# Day            0
# Temperature    0
# Weather        0
# dtype: int64

# %% [markdown]
# # Outlier Detection

# %%
# histogram of Ozone
data_cleaned1['Ozone'].hist()
# Out:
# <Axes: >

# %%
plt.boxplot(data_cleaned1['Ozone'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d08b568e2a0>,
#   <matplotlib.lines.Line2D at 0x7d08b568e5d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d08b568e8a0>,
#   <matplotlib.lines.Line2D at 0x7d08b568eb70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d08b568dfd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d08b568ed50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d08b568f020>],
#  'means': []}

# %%
data_cleaned1.Ozone.describe()
# Out:
# count    157.000000
# mean      38.961783
# std       28.881530
# min        1.000000
# 25%       21.000000
# 50%       30.500000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
#dir(data_box)

# %%
#Extracting outliers
box=plt.boxplot(data_cleaned1['Ozone'])

# %%
for i,j in box.items():
  print(i,j)
# Out:
# whiskers [<matplotlib.lines.Line2D object at 0x7d08b56f5f70>, <matplotlib.lines.Line2D object at 0x7d08b56f6270>]
# caps [<matplotlib.lines.Line2D object at 0x7d08b56f6570>, <matplotlib.lines.Line2D object at 0x7d08b56f68a0>]
# boxes [<matplotlib.lines.Line2D object at 0x7d08b56f5d90>]
# medians [<matplotlib.lines.Line2D object at 0x7d08b56f6ae0>]
# fliers [<matplotlib.lines.Line2D object at 0x7d08b56f6db0>]
# means []

# %%
out=[]
for item in box["fliers"]:
    out.append(item.get_ydata())

out
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %%
[item.get_ydata() for item in box['fliers'] ]  #fliers are outliers
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %%
#To get the whiskers
[item.get_ydata()[0] for item in box['caps']]
# Out:
# [np.float64(1.0), np.float64(80.0)]

# %%
data_cleaned1.loc[(data_cleaned1.Ozone<1) | (data_cleaned1.Ozone>80)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temperature Weather
# 29   115.0  223.0   5.7    5.0   30           79       C
# 61   135.0  269.0   4.1    7.0    1           84       S
# 68    97.0  267.0   6.3    7.0    8           92      PS
# 69    97.0  272.0   5.7    7.0    9           92       C
# 70    85.0  175.0   7.4    7.0   10           89      PS
# 85   108.0  223.0   8.0    7.0   25           85      PS
# 88    82.0  213.0   7.4    7.0   28           88       S
# 98   122.0  255.0   4.0    8.0    7           89       C
# 99    89.0  229.0  10.3    8.0    8           90      PS
# 100  110.0  207.0   8.0    8.0    9           90       C
# 116  168.0  238.0   3.4    8.0   25           81      PS
# 120  118.0  225.0   2.3    8.0   29           94       S
# 121   84.0  237.0   6.3    8.0   30           96       S
# 122   85.0  188.0   6.3    8.0   31           94       C
# 123   96.0  167.0   6.9    9.0    1           91       C
# 126   91.0  189.0   4.6    9.0    4           93      PS

# %%
#data.isnull().sum()

# %%
data_cleaned1.loc[data_cleaned1.Ozone>80,"Ozone"]=80

# %%
data_cleaned1.describe()
# Out:
#             Ozone       Solar        Wind       Month         Day  Temperature
# count  157.000000  157.000000  157.000000  157.000000  157.000000   157.000000
# mean    36.401274  185.998903    9.944586    7.044586   15.955414    77.834395
# std     22.376473   86.676102    3.518675    1.433768    9.003093     9.311454
# min      1.000000    7.000000    1.700000    5.000000    1.000000    56.000000
# 25%     21.000000  127.000000    7.400000    6.000000    8.000000    72.000000
# 50%     30.500000  193.000000    9.700000    7.000000   16.000000    79.000000
# 75%     45.000000  255.000000   11.500000    8.000000   24.000000    84.000000
# max     80.000000  334.000000   20.700000    9.000000   31.000000    97.000000

# %%
plt.boxplot(data_cleaned1["Ozone"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d08b555f890>,
#   <matplotlib.lines.Line2D at 0x7d08b555fb90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d08b555fe90>,
#   <matplotlib.lines.Line2D at 0x7d08b558c1a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d08b555f5f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d08b558c380>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d08b558c620>],
#  'means': []}

# %%
plt.boxplot(data_cleaned1["Wind"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d08b55eca40>,
#   <matplotlib.lines.Line2D at 0x7d08b55ecce0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d08b55ecfe0>,
#   <matplotlib.lines.Line2D at 0x7d08b55ed2e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d08b55ec7a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d08b55ed580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d08b55ed850>],
#  'means': []}

# %%
box_wind=plt.boxplot(data_cleaned1['Wind'])
Extremes=[item.get_ydata()[1] for item in box_wind['caps']]  ##16.6
UE=Extremes[1]
LE=Extremes[0]
print(LE,UE)
# Out:
# 1.7 16.6

# %%
data_cleaned1.loc[data_cleaned1.Wind>UE,"Wind"]=UE

# %%
plt.boxplot(data_cleaned1.Wind)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d08b54bc4d0>,
#   <matplotlib.lines.Line2D at 0x7d08b54bc740>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d08b54bca40>,
#   <matplotlib.lines.Line2D at 0x7d08b54bcc80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d08b54bc380>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d08b54bcef0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d08b54bd160>],
#  'means': []}

# %% [markdown]
# # outlier treatment(Alternative)

# %%
plt.boxplot(data_2.Ozone)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d08b53147a0>,
#   <matplotlib.lines.Line2D at 0x7d08b5314d40>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d08b5314f80>,
#   <matplotlib.lines.Line2D at 0x7d08b53151f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d08b5314620>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d08b53154f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d08b5315790>],
#  'means': []}

# %%
#IQR
Q1=data_2.Ozone.quantile(0.25)
Q3=data_2.Ozone.quantile(0.75)
IQR=Q3-Q1
UE=Q3+1.5*IQR
LE=Q1-1.5*IQR
data_2.loc[data_2.Ozone>UE,"Ozone"]=UE
data_2.loc[data_2.Ozone<LE,"Ozone"]=LE
plt.boxplot(data_2.Ozone)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d08b54be5d0>,
#   <matplotlib.lines.Line2D at 0x7d08b53885c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d08b53888c0>,
#   <matplotlib.lines.Line2D at 0x7d08b5388bf0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d08b54ef9b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d08b5388ec0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d08b5389130>],
#  'means': []}

# %% [markdown]
# # Percentile treatment3*((99%)) treatment

# %%
a=data_2.Wind.quantile(0.99)
b=data_2.Wind.quantile(0.01)
data_2.loc[data_2.Wind>3*a,"Wind"]=3*a
data_2.loc[data_2.Wind<3*b,"Wind"]=3*b

# %%
a=data_3.Ozone.quantile(0.99)
b=data_3.Ozone.quantile(0.01)
data_3.loc[data_2.Ozone>3*a,"Ozone"]=3*a
data_3.loc[data_2.Ozone<3*b,"Ozone"]=3*b
#np.percentile

# %%
data_3.Ozone.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # Scatter plot and Correlation analysis

# %%
plt.scatter(data_cleaned1.Ozone,data_cleaned1.Temperature)

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
#pd.plotting.scatter_matrix(data_cleaned3)
data_cleaned1.Temperature.value_counts().plot(kind="bar")
plt.show()
sns.pairplot(data_cleaned1)
plt.show()

# %%
#Correlation
df_num=data_cleaned1.select_dtypes('number')
df_num.corr(method='pearson')
# Out:
#                 Ozone     Solar      Wind     Month       Day  Temperature
# Ozone        1.000000  0.316564 -0.527243  0.173868 -0.050965     0.666336
# Solar        0.316564  1.000000 -0.045289 -0.089856 -0.144374     0.251665
# Wind        -0.527243 -0.045289  1.000000 -0.140150  0.042043    -0.434164
# Month        0.173868 -0.089856 -0.140150  1.000000  0.061236     0.393321
# Day         -0.050965 -0.144374  0.042043  0.061236  1.000000    -0.115858
# Temperature  0.666336  0.251665 -0.434164  0.393321 -0.115858     1.000000

# %%
sns.heatmap(df_num.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # Transformations

# %% [markdown]
# #### Dummy Variable

# %%
#data_cleaned3.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
#Creating dummy variable for Weather column
data_cleaned1=pd.get_dummies(data_cleaned1,dtype=int,drop_first=True)
data_cleaned1
# Out:
#      Ozone       Solar  Wind  Month  Day  Temperature  Weather_PS  Weather_S
# 0     41.0  190.000000   7.4    5.0    1           67           0          1
# 1     36.0  118.000000   8.0    5.0    2           72           0          0
# 2     12.0  149.000000  12.6    5.0    3           74           1          0
# 3     18.0  313.000000  11.5    5.0    4           62           0          1
# 4     30.5  185.403974  14.3    5.0    5           56           0          1
# ..     ...         ...   ...    ...  ...          ...         ...        ...
# 153   41.0  190.000000   7.4    5.0    1           67           0          0
# 154   30.0  193.000000   6.9    9.0   26           70           1          0
# 155   30.5  145.000000  13.2    9.0   27           77           0          1
# 156   14.0  191.000000  14.3    9.0   28           75           0          1
# 157   18.0  131.000000   8.0    9.0   29           76           0          0
#
# [157 rows x 8 columns]

# %% [markdown]
# #### Feature Scaling

# %%
def get_stand(x):

    return ((x-x.mean())/x.std())

# %%
x=pd.Series([1500,1000,1200,1350,4400,500,300,200])

get_stand(x)
# Out:
# 0    0.144400
# 1   -0.228245
# 2   -0.079187
# 3    0.032606
# 4    2.305745
# 5   -0.600891
# 6   -0.749949
# 7   -0.824479
# dtype: float64

# %%
stand_data=get_stand(data_cleaned1)
stand_data.head()
# Out:
#       Ozone     Solar      Wind     Month       Day  Temperature  Weather_PS  \
# 0  0.205516  0.046161 -0.736932 -1.426023 -1.661142    -1.163556   -0.651576
# 1 -0.017933 -0.784517 -0.558980 -1.426023 -1.550069    -0.626583   -0.651576
# 2 -1.090488 -0.426864  0.805317 -1.426023 -1.438996    -0.411793    1.524965
# 3 -0.822349  1.465238  0.479072 -1.426023 -1.327923    -1.700529   -0.651576
# 4 -0.263727 -0.006864  1.309514 -1.426023 -1.216850    -2.344896   -0.651576
#
#    Weather_S
# 0   1.233896
# 1  -0.805279
# 2  -0.805279
# 3   1.233896
# 4   1.233896

# %%
def get_norm(x):
    return (x-x.min())/(x.max()-x.min())

# %%
x=pd.Series([15,10,12,13.5,40,50,30,29])

get_norm(x)
# Out:
# 0    0.1250
# 1    0.0000
# 2    0.0500
# 3    0.0875
# 4    0.7500
# 5    1.0000
# 6    0.5000
# 7    0.4750
# dtype: float64

# %%
# Select only numerical columns before applying normalization
df_num = data_cleaned1.select_dtypes(include=np.number)
norm_data = get_norm(df_num)
norm_data.head()
# Out:
#       Ozone     Solar      Wind  Month       Day  Temperature  Weather_PS  \
# 0  0.506329  0.559633  0.382550    0.0  0.000000     0.268293         0.0
# 1  0.443038  0.339450  0.422819    0.0  0.033333     0.390244         0.0
# 2  0.139241  0.434251  0.731544    0.0  0.066667     0.439024         1.0
# 3  0.215190  0.935780  0.657718    0.0  0.100000     0.146341         0.0
# 4  0.373418  0.545578  0.845638    0.0  0.133333     0.000000         0.0
#
#    Weather_S
# 0        1.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        1.0

# %%
# !pip uninstall scipy -y
# !pip install --no-cache-dir scipy it
# !pip install --force-reinstall numpy

from scipy import stats
statistic, p_value = stats.shapiro(data_cleaned1['Ozone'])
p_value
# Out:
# Found existing installation: scipy 1.16.1
# Uninstalling scipy-1.16.1:
#   Successfully uninstalled scipy-1.16.1
# Collecting scipy
#   Downloading scipy-1.16.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: it in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from scipy) (2.3.3)
# Downloading scipy-1.16.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 180.4 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.16.1
# Collecting numpy
#   Using cached numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# ERROR: Operation cancelled by user
# ^C

# %%
#Normalization of the data
#from numpy import set_printoptions

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
arr=data_cleaned1.values
scaler.fit(arr)
X_std=scaler.transform(arr)
#scaler.fit_transform(arr)
X_std

# %%
from sklearn.preprocessing import MinMaxScaler
array=data_cleaned1.values
scaler=MinMaxScaler()     #creating an instance for standard scaler
normalized_data=scaler.fit_transform(array)
normalized_data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
arr=data_cleaned1.values
sc.fit(arr)
scaled=sc.transform(arr)
#scaled=sc.fit_transform(arr)
scaled

# %%
data_cleaned1.values

# %%
from sklearn.preprocessing import StandardScaler

array=data_cleaned1.values

scaler=StandardScaler()
rescaledX=scaler.fit_transform(array)

pd.DataFrame(rescaledX).head()

# %%
data_cleaned1.values

# %%
from sklearn.preprocessing import MinMaxScaler
array = data_cleaned1.values

scaler = MinMaxScaler()
rescaledX = scaler.fit_transform(array)

#transformed data
#set_printoptions(precision=2)
print(pd.DataFrame(rescaledX))

# %%
# Standardize data (0 mean, 1 stdev)

# %%
import numpy as np

data_cleaned1["log_ozone"]=np.log(data_cleaned1.Ozone)
data_cleaned1.head()

# %%
data_cleaned1.Ozone.plot(kind="hist")

# %%
data_cleaned1.log_ozone.plot(kind="hist")

# %% [markdown]
# # Speed up the EDA process

# %%
# !pip install pandas-profiling==3.1.0
# !pip install ydata_profiling

# %%
import pandas as pd
data=pd.read_csv("data_clean.csv")

# %%
# !pip install --upgrade numba
# !pip install --upgrade ydata_profiling==4.16

# %%
from pandas_profiling import ProfileReport
import ydata_profiling as pp

# profile=ProfileReport(data, title="Exploratory Data Analysis")
profile=pp.ProfileReport(data, title="Exploratory Data Analysis")

# Generate the report as an HTML file
profile.to_file("report.html")

# %%
# !pip install sweetviz

# %%
# !pip install --upgrade numpy==1.24

# %%
import numpy as np

# %%
import pandas as pd
data=pd.read_csv("data_clean.csv")

# %%
#import pandas_profiling as pp
import sweetviz as sv

sweet_report = sv.analyze(data)
sweet_report.show_html('weather_report.html')

# %%
dict1={'a':[1,2,3,3,3,5],'b':[2,3,4,3,3,6],'c':[5,6,7,3,3,6],'d':[5,6,7,3,3,6]}

# %%
import pandas as pd
df=pd.DataFrame(dict1)

# %%
df

# %%
df[df.duplicated()]

# %%
df1=df.drop_duplicates()

# %%
df1

# %%
df

# %%
df1.reset_index(drop=True)    #after reset, new index created, old index deleted

# %%
df1

# %%
df.drop_duplicates(inplace=True)

# %%
df

# %%
df.reset_index(drop=True,inplace=True)

# %%
df

# %%
# !pip uninstall ydata_profiling -y
# !pip install ydata_profiling
